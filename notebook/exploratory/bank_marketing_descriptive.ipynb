# %%
import os
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import seaborn.objects as so

from scipy.stats import boxcox
from scipy.stats.contingency import association

from sklearn.preprocessing import LabelEncoder

from streamlit_gallery.utils.helper_function import (
    get_var, 
    cat_value_count, 
    outlier_thresholds, 
    loc_potential_outliers, 
    any_potential_outlier, 
    delete_potential_outlier, 
    delete_potential_outlier_list, 
    plot_continuous, 
    plot_categorical, 
    plot_features_label, 
    plot_label_features 
)

pd.set_option('display.max_columns', None)

# %%
color_palette = ["#1E1A0F", "#3F3128", "#644B35", "#A76F53", "#DCA98E", "#D7C9AC", "#689399", "#575735", "#343D22", "#152411"]
fp = matplotlib.font_manager.FontProperties(
    fname='/Fonts/roboto/Roboto-Condensed.ttf')
sns.set_palette(color_palette)
sns.set_style("whitegrid", {"grid.color": "#ffffff", "axes.facecolor": "w", 'figure.facecolor':'white'})

# %%
sns.palplot(sns.color_palette())

# %%
cmap_name = 'custom_palette'
cm = plt.cm.colors.LinearSegmentedColormap.from_list(cmap_name, color_palette, N=len(color_palette))

# %% [markdown]
# # Dataset Info
#
#    #### Source:
#    https://archive.ics.uci.edu/dataset/222/bank+marketing

# %% [markdown]
#    #### Train data:
# | No. | Features | Description |
# | :-------- | :-------- | :-------- |
# | 1. | age | (numeric) |
# | 2. | job | type of job (categorical: "admin.","unknown","unemployed","management","housemaid","entrepreneur","student","blue-collar","self-employed","retired","technician","services")  |
# | 3. | marital | marital status (categorical: "married","divorced","single"; note: "divorced" means divorced or widowed) |
# | 4. | education | (categorical: "unknown","secondary","primary","tertiary") |
# | 5. | default | has credit in default? (binary: "yes","no") |
# | 6. | balance | average yearly balance, in euros (numeric)  |
# | 7. | housing | has housing loan? (binary: "yes","no") |
# | 8. | loan | has personal loan? (binary: "yes","no") |
# | 9. | contact | contact communication type (categorical: "unknown","telephone","cellular") |
# | 10. | day | last contact day of the month (numeric) |
# | 11. | month | last contact month of year (categorical: "jan", "feb", "mar", ..., "nov", "dec") |
# | 12. | duration | last contact duration, in seconds (numeric) |
# | 13. | campaign | number of contacts performed during this campaign and for this client (numeric, includes last contact) |
# | 14. | pdays | number of days that passed by after the client was last contacted from a previous campaign (numeric, -1 means client was not previously contacted) |
# | 15. | previous | number of contacts performed before this campaign and for this client (numeric) |
# | 16. | poutcome | outcome of the previous marketing campaign (categorical: "unknown","other","failure","success") |
#
#   #### Target variable:
# | No. | Target | Description |
# | :-------- | :-------- | :-------- |
# | 17. | y | has the client subscribed a term deposit? (binary: "yes","no") |

# %% [markdown]
# # Exploratory Data Analysis

# %%
df = (pd
      .read_csv("bank-full.csv", sep=';')
      .rename(columns={'y': 'deposit'})
      .pipe(lambda df_: df_.assign(deposit=np.where(df_.deposit == "no", 0, 1)))
      )
df.head()
# Out:
#    age           job  marital  education default  balance housing loan  \
# 0   58    management  married   tertiary      no     2143     yes   no
# 1   44    technician   single  secondary      no       29     yes   no
# 2   33  entrepreneur  married  secondary      no        2     yes  yes
# 3   47   blue-collar  married    unknown      no     1506     yes   no
# 4   33       unknown   single    unknown      no        1      no   no
#
#    contact  day month  duration  campaign  pdays  previous poutcome  deposit
# 0  unknown    5   may       261         1     -1         0  unknown        0
# 1  unknown    5   may       151         1     -1         0  unknown        0
# 2  unknown    5   may        76         1     -1         0  unknown        0
# 3  unknown    5   may        92         1     -1         0  unknown        0
# 4  unknown    5   may       198         1     -1         0  unknown        0

# %%
print(f'Train data \nNumber of rows : {df.shape[0]}\nNumber of columns: {df.shape[1]}')
# Out:
# Train data
# Number of rows : 45211
# Number of columns: 17

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45211 entries, 0 to 45210
# Data columns (total 17 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   age        45211 non-null  int64
#  1   job        45211 non-null  object
#  2   marital    45211 non-null  object
#  3   education  45211 non-null  object
#  4   default    45211 non-null  object
#  5   balance    45211 non-null  int64
#  6   housing    45211 non-null  object
#  7   loan       45211 non-null  object
#  8   contact    45211 non-null  object
#  9   day        45211 non-null  int64
#  10  month      45211 non-null  object
#  11  duration   45211 non-null  int64
#  12  campaign   45211 non-null  int64
#  13  pdays      45211 non-null  int64
#  14  previous   45211 non-null  int64
#  15  poutcome   45211 non-null  object
#  16  deposit    45211 non-null  int64
# dtypes: int64(8), object(9)
# memory usage: 5.9+ MB

# %%
(df
 .deposit
 .value_counts(normalize=True)
 .to_frame()
 .reset_index()
)
# Out:
#    index   deposit
# 0      0  0.883015
# 1      1  0.116985

# %%
(so
 .Plot((df
        .deposit
        .value_counts(normalize=True)
        .to_frame()
        .reset_index()
       ),
       x='index',
       y='deposit')
 .add(so.Bar(),)
 .scale(x=so.Continuous().tick(between=(0, 1), count=2))
 .label(x='Deposit',
        y='Proportion',
        color=str.capitalize,
        title=f'Proportion of Deposit')
 .theme({"axes.prop_cycle": matplotlib.cycler(color=[color_palette[0]]), "axes.facecolor": "w", "grid.color": "#ffffff"})
)

# %% [markdown]
# ### Univariate Analysis (Continuous)

# %%
df.describe(percentiles = [.25,.50,.75,.95,.99])
# Out:
#                 age        balance           day      duration      campaign  \
# count  45211.000000   45211.000000  45211.000000  45211.000000  45211.000000
# mean      40.936210    1362.272058     15.806419    258.163080      2.763841
# std       10.618762    3044.765829      8.322476    257.527812      3.098021
# min       18.000000   -8019.000000      1.000000      0.000000      1.000000
# 25%       33.000000      72.000000      8.000000    103.000000      1.000000
# 50%       39.000000     448.000000     16.000000    180.000000      2.000000
# 75%       48.000000    1428.000000     21.000000    319.000000      3.000000
# 95%       59.000000    5768.000000     29.000000    751.000000      8.000000
# 99%       71.000000   13164.900000     31.000000   1269.000000     16.000000
# max       95.000000  102127.000000     31.000000   4918.000000     63.000000
#
#               pdays      previous       deposit
# count  45211.000000  45211.000000  45211.000000
# mean      40.197828      0.580323      0.116985
# std      100.128746      2.303441      0.321406
# min       -1.000000      0.000000      0.000000
# 25%       -1.000000      0.000000      0.000000
# 50%       -1.000000      0.000000      0.000000
# 75%       -1.000000      0.000000      0.000000
# 95%      317.000000      3.000000      1.000000
# 99%      370.000000      8.900000      1.000000
# max      871.000000    275.000000      1.000000

# %%
print(f'Based on 1.5xIQR outlier detection formula:\n')
for col in ['age', 'balance', 'day', 'duration', 'campaign', 'pdays', 'previous']:
    print(f'Column {col}: Detected total of {any_potential_outlier(df, col)} potential outliers')
# Out:
# Based on 1.5xIQR outlier detection formula:
#
# Column age: Detected total of 0 potential outliers
# Column balance: Detected total of 360 potential outliers
# Column day: Detected total of 0 potential outliers
# Column duration: Detected total of 97 potential outliers
# Column campaign: Detected total of 331 potential outliers
# Column pdays: Detected total of 11 potential outliers
# Column previous: Detected total of 582 potential outliers

# %%
plot_continuous(df, 'age', 'Age Distribution', 'yo')

# %%
#Trying log-transformation
(so
 .Plot(df
       .age)
 .add(so.Bars(color=color_palette[0]), 
      so.Hist("density", bins=30),)
 .add(so.Line(), so.KDE())
 .label(x='age',
        y='Frequency',
        color=str.capitalize,
        title='Age Distribution (log)',)
 .theme({"axes.facecolor": "w", "grid.color": "#ffffff"})
 .on(matplotlib.figure.Figure(figsize=(8,4)))
 .plot()
)

# %%
loc_potential_outliers(df, "age")
# Out:
# Detected total of 0 potential outliers based on 1.5xIQR
# Empty DataFrame
# Columns: [age, job, marital, education, default, balance, housing, loan, contact, day, month, duration, campaign, pdays, previous, poutcome, deposit]
# Index: []

# %%
#Trying log-transformation
(so
 .Plot(df
       .age
       .transform(np.log),)
 .add(so.Bars(color=color_palette[0]), so.Hist(bins=50))
 .label(x='age',
        y='Frequency',
        color=str.capitalize,
        title='Age Distribution (log)',)
 .theme({"axes.facecolor": "w", "grid.color": "#ffffff"})
 .on(matplotlib.figure.Figure(figsize=(8,4)))
 .plot()
)

# %%
#Trying box-cox-transformation
print(f'Box-Cox Transformation applied with lambda = {boxcox(df.age)[1]}')

(so
 .Plot(pd
       .Series(boxcox(df.age)[0]))
 .add(so.Bars(color=color_palette[0]), so.Hist(bins=50))
 .label(x='age',
        y='Frequency',
        color=str.capitalize,
        title='Age Distribution (Box-Cox)',)
 .theme({"axes.facecolor": "w", "grid.color": "#ffffff"})
 .on(matplotlib.figure.Figure(figsize=(8,4)))
 .plot()
)
# Out:
# Box-Cox Transformation applied with lambda = -0.16368117914120728

# %%
plot_continuous(df, 'balance', 'Balance Distribution', '$')

# %%
(df
 .loc[df.balance < 0]
)
# Out:
#        age          job   marital  education default  balance housing loan  \
# 25      44       admin.   married  secondary      no     -372     yes   no
# 28      46   management    single  secondary      no     -246     yes   no
# 36      25  blue-collar   married  secondary      no       -7     yes   no
# 37      53   technician   married  secondary      no       -3      no   no
# 45      36       admin.    single    primary      no     -171     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 44626   31     services    single  secondary      no     -205      no   no
# 44629   28  blue-collar    single  secondary      no      -46     yes   no
# 44836   33  blue-collar   married    primary      no     -195      no   no
# 44908   48   management  divorced   tertiary      no     -130     yes   no
# 44964   21  blue-collar    single    primary      no      -42      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 25      unknown    5   may       172         1     -1         0  unknown
# 28      unknown    5   may       255         2     -1         0  unknown
# 36      unknown    5   may       365         1     -1         0  unknown
# 37      unknown    5   may      1666         1     -1         0  unknown
# 45      unknown    5   may       242         1     -1         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 44626  cellular    1   sep       481         1    579         1  failure
# 44629  cellular    1   sep       199         1     92        14  success
# 44836   unknown   20   sep         9         1     -1         0  unknown
# 44908  cellular   29   sep       110         2     61         9  failure
# 44964   unknown   10   oct         5         1     -1         0  unknown
#
#        deposit
# 25           0
# 28           0
# 36           0
# 37           0
# 45           0
# ...        ...
# 44626        1
# 44629        1
# 44836        0
# 44908        0
# 44964        0
#
# [3766 rows x 17 columns]

# %%
loc_potential_outliers(df, "balance")
# Out:
# Detected total of 360 potential outliers based on 1.5xIQR
#        age          job   marital  education default  balance housing loan  \
# 334     45   management  divorced   tertiary      no    24598     yes   no
# 446     39   technician    single    unknown      no    45248     yes   no
# 920     44       admin.   married  secondary      no    58544     yes   no
# 2065    55      retired   married  secondary      no    18722     yes   no
# 2343    26   technician    single  secondary      no    24299     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 44521   42   management   married   tertiary      no    27696      no   no
# 44861   55   management  divorced   tertiary      no    26306     yes   no
# 44874   36   unemployed   married  secondary      no    17458      no   no
# 45019   57       admin.   married  secondary      no    16873      no   no
# 45127   67  blue-collar   married  secondary      no    16353      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 334     unknown    5   may       313         3     -1         0  unknown
# 446     unknown    6   may      1623         1     -1         0  unknown
# 920     unknown    7   may       144         2     -1         0  unknown
# 2065    unknown   12   may       128         2     -1         0  unknown
# 2343    unknown   13   may       704         1     -1         0  unknown
# ...         ...  ...   ...       ...       ...    ...       ...      ...
# 44521  cellular   11   aug       370         1     91         7  success
# 44861  cellular   23   sep        84         1    589         4  failure
# 44874  cellular   23   sep       390         2     -1         0  unknown
# 45019  cellular   14   oct       219         3    372         1  failure
# 45127  cellular   27   oct       223         2     -1         0  unknown
#
#        deposit
# 334          0
# 446          1
# 920          0
# 2065         0
# 2343         0
# ...        ...
# 44521        1
# 44861        0
# 44874        0
# 45019        0
# 45127        0
#
# [360 rows x 17 columns]

# %%
(so
 .Plot((df
         .day
         .value_counts()
         .sort_index()
         .to_frame()
         .reset_index()
        ),
       x="index",
       y="day")
 .add(so.Line(color=color_palette[0]))
 .label(x="Day",
        y='Frequency',
        color=str.capitalize,
        title=f'Day of the month Distribution')
 .theme({"axes.facecolor": "w", "grid.color": "#ffffff"})
 .plot()
)

# %%
plot_continuous(df, 'duration', 'Duration Distribution', 'sec')

# %%
loc_potential_outliers(df, "duration")
# Out:
# Detected total of 97 potential outliers based on 1.5xIQR
#        age          job   marital  education default  balance housing loan  \
# 152     40   management   married   tertiary      no       -4     yes   no
# 600     38  blue-collar   married  secondary      no      384     yes   no
# 1034    41  blue-collar    single  secondary      no      277     yes   no
# 1416    43   management  divorced   tertiary      no      388     yes   no
# 1731    41  blue-collar   married    primary      no      406     yes   no
# ...    ...          ...       ...        ...     ...      ...     ...  ...
# 42265   63   management   married   tertiary      no     5112      no   no
# 42534   68      retired   married  secondary      no     1443      no   no
# 43032   38     services   married  secondary      no      775      no   no
# 43901   50   technician    single   tertiary      no        2      no   no
# 44602   45     services    single  secondary      no      955      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 152      unknown    5   may      2033         1     -1         0  unknown
# 600      unknown    6   may      1906         3     -1         0  unknown
# 1034     unknown    7   may      2177         4     -1         0  unknown
# 1416     unknown    8   may      2087         2     -1         0  unknown
# 1731     unknown    9   may      2462         1     -1         0  unknown
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 42265  telephone   13   nov      2184         2     95         3  failure
# 42534  telephone   21   dec      2062         2    257         1  success
# 43032   cellular   12   feb      1835         3    182         2  success
# 43901    unknown   10   jun      2389         1     -1         0  unknown
# 44602    unknown   27   aug      3785         1     -1         0  unknown
#
#        deposit
# 152          0
# 600          0
# 1034         0
# 1416         1
# 1731         0
# ...        ...
# 42265        1
# 42534        1
# 43032        1
# 43901        0
# 44602        0
#
# [97 rows x 17 columns]

# %%
(df
 .loc[df.duration == 0]
)
# Out:
#        age           job  marital  education default  balance housing loan  \
# 6424    53    management  married    primary      no      351     yes   no
# 22937   35    technician  married  secondary      no     5535      no   no
# 36425   31  entrepreneur  married  secondary      no      162     yes  yes
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 6424    unknown   27   may         0         4     -1         0  unknown
# 22937  cellular   26   aug         0        15     -1         0  unknown
# 36425  cellular   11   may         0         2     -1         0  unknown
#
#        deposit
# 6424         0
# 22937        0
# 36425        0

# %%
#Trying log-transformation
(so
 .Plot(df
       .duration
       .transform(lambda x: np.log(x+0.01)),)
 .add(so.Bars(color=color_palette[0]), so.Hist(bins=50))
 .label(x='duration',
        y='Frequency',
        color=str.capitalize,
        title='Duration Distribution (log(x+0.01))',)
 .theme({"axes.facecolor": "w", "grid.color": "#ffffff"})
 .on(matplotlib.figure.Figure(figsize=(8,4)))
 .plot()
)

# %%
#Trying box-cox-transformation
print(f'Box-Cox Transformation applied with lambda = {boxcox(df.duration.transform(lambda x: x+0.01))[1]}')

(so
 .Plot(pd
       .Series(boxcox(df.duration.transform(lambda x: x+0.01))[0]))
 .add(so.Bars(color=color_palette[0]), so.Hist(bins=50))
 .label(x='duration',
        y='Frequency',
        color=str.capitalize,
        title='Duration Distribution (Box-Cox(x+0.01))',)
 .theme({"axes.facecolor": "w", "grid.color": "#ffffff"})
 .on(matplotlib.figure.Figure(figsize=(8,4)))
 .plot()
)
# Out:
# Box-Cox Transformation applied with lambda = 0.1479489780800578

# %%
plot_continuous(df, 'campaign', 'Campaign Distribution', '')

# %%
loc_potential_outliers(df, "campaign")
# Out:
# Detected total of 331 potential outliers based on 1.5xIQR
#        age            job   marital  education default  balance housing loan  \
# 2706    46         admin.  divorced   tertiary      no     3749     yes   no
# 3079    28    blue-collar   married    primary      no        0      no   no
# 3331    50   entrepreneur   married    primary      no      461     yes   no
# 3475    42     management  divorced   tertiary      no      497      no   no
# 3483    59     management   married   tertiary      no     2319     yes   no
# ...    ...            ...       ...        ...     ...      ...     ...  ...
# 30917   28     technician    single   tertiary      no     4987      no   no
# 31076   38  self-employed   married  secondary      no      187      no  yes
# 31136   28        student    single  secondary      no        0      no   no
# 31361   29         admin.    single   tertiary      no      261      no   no
# 33858   26     management    single   tertiary      no     6791      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 2706     unknown   13   may        69        19     -1         0  unknown
# 3079     unknown   14   may        17        24     -1         0  unknown
# 3331     unknown   15   may       651        32     -1         0  unknown
# 3475     unknown   15   may        84        22     -1         0  unknown
# 3483     unknown   15   may       132        32     -1         0  unknown
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 30917   cellular    9   feb       253        21     -1         0  unknown
# 31076  telephone   16   feb        66        21     -1         0  unknown
# 31136   cellular   18   feb       209        20     -1         0  unknown
# 31361   cellular   17   mar       136        19     -1         0  unknown
# 33858  telephone   29   apr       164        23     -1         0  unknown
#
#        deposit
# 2706         0
# 3079         0
# 3331         1
# 3475         0
# 3483         0
# ...        ...
# 30917        1
# 31076        0
# 31136        1
# 31361        0
# 33858        0
#
# [331 rows x 17 columns]

# %%
#Trying log-transformation
(so
 .Plot(df
       .campaign
       .transform(np.log))
 .add(so.Bars(color=color_palette[0]), so.Hist(bins=10))
 .label(x='campaign',
        y='Frequency',
        color=str.capitalize,
        title='Campaign Distribution (log)',)
 .theme({"axes.facecolor": "w", "grid.color": "#ffffff"})
 .on(matplotlib.figure.Figure(figsize=(8,4)))
 .plot()
)

# %%
plot_continuous(df, 'pdays', 'Pdays Distribution', 'days')

# %%
loc_potential_outliers(df, "pdays")
# Out:
# Detected total of 11 potential outliers based on 1.5xIQR
#        age          job   marital  education default  balance housing loan  \
# 44530   34  blue-collar   married  secondary      no      320     yes   no
# 44698   34   technician   married  secondary      no      384     yes   no
# 44785   43  blue-collar   married  secondary      no      408     yes   no
# 44829   37   management  divorced   tertiary      no      488     yes   no
# 44837   35   management    single   tertiary      no      151      no   no
# 44858   31    housemaid   married  secondary      no      243     yes   no
# 44924   35  blue-collar   married  secondary      no      137      no  yes
# 45024   47       admin.   married  secondary      no     1387     yes   no
# 45037   45   management    single   tertiary      no     2048     yes   no
# 45120   32   technician   married  secondary      no     1547      no   no
# 45146   49   unemployed  divorced   tertiary      no      780      no   no
#
#         contact  day month  duration  campaign  pdays  previous poutcome  \
# 44530  cellular   12   aug       352         1    828         2  failure
# 44698  cellular    6   sep       127         2    831         1    other
# 44785   unknown   14   sep         6         1    838         3    other
# 44829  cellular   17   sep       328         1    854         2  failure
# 44837   unknown   20   sep        11         1    850         2  failure
# 44858  cellular   23   sep       305         2    842         1  failure
# 44924   unknown    4   oct         5         1    808        12  failure
# 45024  cellular   14   oct       158         1    826         1  failure
# 45037  cellular   18   oct       310         1    804         1  failure
# 45120  cellular   26   oct       289         1    805         4    other
# 45146  cellular    8   nov       148         1    871         2  failure
#
#        deposit
# 44530        1
# 44698        0
# 44785        0
# 44829        1
# 44837        0
# 44858        1
# 44924        0
# 45024        0
# 45037        1
# 45120        1
# 45146        0

# %%
#Trying log-transformation
(so
 .Plot(df
       .pdays
       .transform(np.log))
 .add(so.Bars(color=color_palette[0]), so.Hist(bins=50))
 .label(x='pdays',
        y='Frequency',
        color=str.capitalize,
        title='Pdays Distribution (log)',)
 .theme({"axes.facecolor": "w", "grid.color": "#ffffff"})
 .on(matplotlib.figure.Figure(figsize=(8,4)))
 .plot()
)

# %%
(df
 .loc[df.pdays == -1]
)
# Out:
#        age           job   marital  education default  balance housing loan  \
# 0       58    management   married   tertiary      no     2143     yes   no
# 1       44    technician    single  secondary      no       29     yes   no
# 2       33  entrepreneur   married  secondary      no        2     yes  yes
# 3       47   blue-collar   married    unknown      no     1506     yes   no
# 4       33       unknown    single    unknown      no        1      no   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45203   23       student    single   tertiary      no      113      no   no
# 45205   25    technician    single  secondary      no      505      no  yes
# 45206   51    technician   married   tertiary      no      825      no   no
# 45207   71       retired  divorced    primary      no     1729      no   no
# 45209   57   blue-collar   married  secondary      no      668      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 0        unknown    5   may       261         1     -1         0  unknown
# 1        unknown    5   may       151         1     -1         0  unknown
# 2        unknown    5   may        76         1     -1         0  unknown
# 3        unknown    5   may        92         1     -1         0  unknown
# 4        unknown    5   may       198         1     -1         0  unknown
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 45203   cellular   17   nov       266         1     -1         0  unknown
# 45205   cellular   17   nov       386         2     -1         0  unknown
# 45206   cellular   17   nov       977         3     -1         0  unknown
# 45207   cellular   17   nov       456         2     -1         0  unknown
# 45209  telephone   17   nov       508         4     -1         0  unknown
#
#        deposit
# 0            0
# 1            0
# 2            0
# 3            0
# 4            0
# ...        ...
# 45203        1
# 45205        1
# 45206        1
# 45207        1
# 45209        0
#
# [36954 rows x 17 columns]

# %%
plot_continuous(df, 'previous', 'Previous Distribution', '')

# %%
loc_potential_outliers(df, "previous")
# Out:
# Detected total of 582 potential outliers based on 1.5xIQR
#        age           job   marital  education default  balance housing loan  \
# 24136   34    management   married   tertiary      no     1770     yes   no
# 24295   35    technician  divorced   tertiary      no     1718     yes  yes
# 24331   36    management   married   tertiary      no     5057     yes   no
# 24506   42    unemployed   married    unknown      no      970     yes   no
# 24556   44    management   married   tertiary      no     1451     yes   no
# ...    ...           ...       ...        ...     ...      ...     ...  ...
# 45171   33        admin.    single  secondary      no      690      no   no
# 45172   30    technician    single   tertiary      no     2325      no   no
# 45199   34   blue-collar    single  secondary      no     1475     yes   no
# 45204   73       retired   married  secondary      no     2850      no   no
# 45210   37  entrepreneur   married  secondary      no     2971      no   no
#
#          contact  day month  duration  campaign  pdays  previous poutcome  \
# 24136    unknown    6   nov        26         1    101        11    other
# 24295   cellular   17   nov        74         1    167        16    other
# 24331   cellular   17   nov        70         1    166        10  failure
# 24506  telephone   17   nov       725         1    119        10  success
# 24556   cellular   17   nov       157         3    150        12  failure
# ...          ...  ...   ...       ...       ...    ...       ...      ...
# 45171   cellular   10   nov       223         3    555        16  failure
# 45172   cellular   10   nov       134         1     92         8  success
# 45199   cellular   16   nov      1166         3    530        12    other
# 45204   cellular   17   nov       300         1     40         8  failure
# 45210   cellular   17   nov       361         2    188        11    other
#
#        deposit
# 24136        0
# 24295        0
# 24331        0
# 24506        0
# 24556        0
# ...        ...
# 45171        0
# 45172        0
# 45199        0
# 45204        1
# 45210        0
#
# [582 rows x 17 columns]

# %% [markdown]
# ### Univariate Analysis (Categorical)

# %%
cat_value_count(df, "job")
# Out:
# This categorical predictor has 12 unique values
#
#                 abs_count  norm_count    cumsum  mean_target
# blue-collar       9732.0    0.215257  0.215257     0.072750
# management        9458.0    0.209197  0.424454     0.137556
# technician        7597.0    0.168034  0.592489     0.110570
# admin.            5171.0    0.114375  0.706863     0.122027
# services          4154.0    0.091880  0.798744     0.088830
# retired           2264.0    0.050076  0.848820     0.227915
# self-employed     1579.0    0.034925  0.883745     0.118429
# entrepreneur      1487.0    0.032890  0.916635     0.082717
# unemployed        1303.0    0.028820  0.945456     0.155027
# housemaid         1240.0    0.027427  0.972883     0.087903
# student            938.0    0.020747  0.993630     0.286780
# unknown            288.0    0.006370  1.000000     0.118056

# %%
plot_categorical(df, "job")

# %%
cat_value_count(df, "marital")
# Out:
# This categorical predictor has 3 unique values
#
#            abs_count  norm_count    cumsum  mean_target
# married     27214.0    0.601933  0.601933     0.101235
# single      12790.0    0.282896  0.884829     0.149492
# divorced     5207.0    0.115171  1.000000     0.119455

# %%
plot_categorical(df, "marital")

# %%
cat_value_count(df, "education")
# Out:
# This categorical predictor has 4 unique values
#
#             abs_count  norm_count    cumsum  mean_target
# secondary    23202.0    0.513194  0.513194     0.105594
# tertiary     13301.0    0.294198  0.807392     0.150064
# primary       6851.0    0.151534  0.958926     0.086265
# unknown       1857.0    0.041074  1.000000     0.135703

# %%
plot_categorical(df, "education")

# %%
cat_value_count(df, "default")
# Out:
# This categorical predictor has 2 unique values
#
#       abs_count  norm_count    cumsum  mean_target
# no     44396.0    0.981973  0.981973     0.117961
# yes      815.0    0.018027  1.000000     0.063804

# %%
plot_categorical(df, "default")

# %%
cat_value_count(df, "housing")
# Out:
# This categorical predictor has 2 unique values
#
#       abs_count  norm_count    cumsum  mean_target
# yes    25130.0    0.555838  0.555838     0.077000
# no     20081.0    0.444162  1.000000     0.167024

# %%
plot_categorical(df, "housing")

# %%
cat_value_count(df, "loan")
# Out:
# This categorical predictor has 2 unique values
#
#       abs_count  norm_count    cumsum  mean_target
# no     37967.0    0.839774  0.839774     0.126557
# yes     7244.0    0.160226  1.000000     0.066814

# %%
plot_categorical(df, "loan")

# %%
cat_value_count(df, "contact")
# Out:
# This categorical predictor has 3 unique values
#
#             abs_count  norm_count    cumsum  mean_target
# cellular     29285.0    0.647741  0.647741     0.149189
# unknown      13020.0    0.287983  0.935724     0.040707
# telephone     2906.0    0.064276  1.000000     0.134205

# %%
plot_categorical(df, "contact")

# %%
cat_value_count(df,
                'month',
                reindex=['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'])
# Out:
# This categorical predictor has 12 unique values
#
#       abs_count  norm_count    cumsum  mean_target
# jan     1403.0    0.031032  0.031032     0.101212
# feb     2649.0    0.058592  0.089624     0.166478
# mar      477.0    0.010551  0.100175     0.519916
# apr     2932.0    0.064851  0.165026     0.196794
# may    13766.0    0.304483  0.469510     0.067195
# jun     5341.0    0.118135  0.587645     0.102228
# jul     6895.0    0.152507  0.740152     0.090935
# aug     6247.0    0.138174  0.878326     0.110133
# sep      579.0    0.012807  0.891133     0.464594
# oct      738.0    0.016323  0.907456     0.437669
# nov     3970.0    0.087810  0.995267     0.101511
# dec      214.0    0.004733  1.000000     0.467290

# %%
plot_categorical(df, "month", ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'])

# %%
cat_value_count(df, "poutcome")
# Out:
# This categorical predictor has 4 unique values
#
#           abs_count  norm_count    cumsum  mean_target
# unknown    36959.0    0.817478  0.817478     0.091615
# failure     4901.0    0.108403  0.925881     0.126097
# other       1840.0    0.040698  0.966579     0.166848
# success     1511.0    0.033421  1.000000     0.647253

# %%
plot_categorical(df, "poutcome")

# %% [markdown]
# ### Bivariate Analysis (Numerical Features v Label)

# %%
(so
 .Plot(df, x='age', color='deposit')
 .add(so.Area(), 
      so.KDE())
 .label(x='age',
        y='Frequency',
        color=str.capitalize,
        title='Age Distribution')
 .theme({"axes.facecolor": "w", "grid.color": "#ffffff"})
)

# %%
(df
 .groupby('deposit')
 .boxplot(column=['age'])
);

# %%
(df
 .groupby('deposit')
 .boxplot(column=['balance'])
)
plt.ylim(-5000,6000);

# %%
fig, ax = plt.subplots()
fig = (sns
       .boxplot(df,
                x='deposit',
                y='balance',
                orient='v',)
       .figure
      )
ax.set_ylim(-5000,6000);

# %%
(df
 .groupby('deposit')
 .boxplot(column=['day'])
);

# %%
(df
 .groupby('deposit')
 .boxplot(column=['duration'])
);

# %%
fig, ax = plt.subplots()
fig = (sns
       .boxplot(df,
                x='deposit',
                y='duration',
                orient='v',)
       .figure
      )
fig

# %%
(df
 .groupby('deposit')
 .boxplot(column=['campaign'])
)
plt.ylim(0, 10);

# %%
(df
 .groupby('deposit')
 .boxplot(column=['previous'])
)
plt.ylim(0,2);

# %% [markdown]
# ### Bivariate Analysis (Categorical Features v Label)

# %%
plot_features_label(df, "job")

# %%
plot_label_features(df, "job")

# %%
plot_features_label(df, "marital")

# %%
plot_label_features(df, "marital")

# %%
plot_features_label(df, "education")

# %%
plot_label_features(df, "education")

# %%
plot_features_label(df, "default")

# %%
plot_label_features(df, "default")

# %%
plot_features_label(df, "housing")

# %%
plot_label_features(df, "housing")

# %%
plot_features_label(df, "loan")

# %%
plot_label_features(df, "loan")

# %%
plot_features_label(df, "contact")

# %%
plot_label_features(df, "contact")

# %%
plot_features_label(df, "month", ['jan', 'feb', 'mar', 'apr', 'may', 'jun', 'jul', 'aug', 'sep', 'oct', 'nov', 'dec'])

# %%
plot_label_features(df, "month")

# %%
plot_features_label(df, "poutcome")

# %%
plot_label_features(df, "poutcome")

# %%
(df
 .select_dtypes('int')
 .corr(method='spearman')
 .style
 .background_gradient(cmap=cm, axis=None)
 .set_sticky(axis="index")
 .set_sticky(axis="columns")
)
# Out:
# <style type="text/css">
# #T_c757c thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_c757c tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# #T_c757c thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: inherit;
#   top: 0px;
#   z-index: 2;
# }
# #T_c757c_row0_col0, #T_c757c_row1_col1, #T_c757c_row2_col2, #T_c757c_row3_col3, #T_c757c_row4_col4, #T_c757c_row5_col5, #T_c757c_row5_col6, #T_c757c_row6_col5, #T_c757c_row6_col6, #T_c757c_row7_col7 {
#   background-color: #152411;
#   color: #f1f1f1;
# }
# #T_c757c_row0_col1, #T_c757c_row0_col4, #T_c757c_row1_col0, #T_c757c_row1_col2, #T_c757c_row1_col3, #T_c757c_row1_col5, #T_c757c_row1_col6, #T_c757c_row1_col7, #T_c757c_row2_col1, #T_c757c_row3_col1, #T_c757c_row3_col5, #T_c757c_row3_col6, #T_c757c_row4_col0, #T_c757c_row5_col1, #T_c757c_row5_col3, #T_c757c_row6_col1, #T_c757c_row6_col3, #T_c757c_row7_col1 {
#   background-color: #3f3128;
#   color: #f1f1f1;
# }
# #T_c757c_row0_col2, #T_c757c_row0_col3, #T_c757c_row0_col5, #T_c757c_row0_col6, #T_c757c_row0_col7, #T_c757c_row1_col4, #T_c757c_row2_col0, #T_c757c_row2_col3, #T_c757c_row2_col5, #T_c757c_row2_col6, #T_c757c_row2_col7, #T_c757c_row3_col0, #T_c757c_row3_col2, #T_c757c_row3_col4, #T_c757c_row4_col1, #T_c757c_row4_col3, #T_c757c_row4_col5, #T_c757c_row4_col6, #T_c757c_row4_col7, #T_c757c_row5_col0, #T_c757c_row5_col2, #T_c757c_row5_col4, #T_c757c_row6_col0, #T_c757c_row6_col2, #T_c757c_row6_col4, #T_c757c_row7_col0, #T_c757c_row7_col2, #T_c757c_row7_col4 {
#   background-color: #1e1a0f;
#   color: #f1f1f1;
# }
# #T_c757c_row2_col4, #T_c757c_row4_col2, #T_c757c_row5_col7, #T_c757c_row6_col7, #T_c757c_row7_col5, #T_c757c_row7_col6 {
#   background-color: #644b35;
#   color: #f1f1f1;
# }
# #T_c757c_row3_col7, #T_c757c_row7_col3 {
#   background-color: #dca98e;
#   color: #000000;
# }
# </style>
# <table id="T_c757c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c757c_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_c757c_level0_col1" class="col_heading level0 col1" >balance</th>
#       <th id="T_c757c_level0_col2" class="col_heading level0 col2" >day</th>
#       <th id="T_c757c_level0_col3" class="col_heading level0 col3" >duration</th>
#       <th id="T_c757c_level0_col4" class="col_heading level0 col4" >campaign</th>
#       <th id="T_c757c_level0_col5" class="col_heading level0 col5" >pdays</th>
#       <th id="T_c757c_level0_col6" class="col_heading level0 col6" >previous</th>
#       <th id="T_c757c_level0_col7" class="col_heading level0 col7" >deposit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c757c_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_c757c_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_c757c_row0_col1" class="data row0 col1" >0.096380</td>
#       <td id="T_c757c_row0_col2" class="data row0 col2" >-0.008948</td>
#       <td id="T_c757c_row0_col3" class="data row0 col3" >-0.033257</td>
#       <td id="T_c757c_row0_col4" class="data row0 col4" >0.037136</td>
#       <td id="T_c757c_row0_col5" class="data row0 col5" >-0.017468</td>
#       <td id="T_c757c_row0_col6" class="data row0 col6" >-0.011900</td>
#       <td id="T_c757c_row0_col7" class="data row0 col7" >-0.008750</td>
#     </tr>
#     <tr>
#       <th id="T_c757c_level0_row1" class="row_heading level0 row1" >balance</th>
#       <td id="T_c757c_row1_col0" class="data row1 col0" >0.096380</td>
#       <td id="T_c757c_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_c757c_row1_col2" class="data row1 col2" >0.001329</td>
#       <td id="T_c757c_row1_col3" class="data row1 col3" >0.042651</td>
#       <td id="T_c757c_row1_col4" class="data row1 col4" >-0.030959</td>
#       <td id="T_c757c_row1_col5" class="data row1 col5" >0.069676</td>
#       <td id="T_c757c_row1_col6" class="data row1 col6" >0.079536</td>
#       <td id="T_c757c_row1_col7" class="data row1 col7" >0.100295</td>
#     </tr>
#     <tr>
#       <th id="T_c757c_level0_row2" class="row_heading level0 row2" >day</th>
#       <td id="T_c757c_row2_col0" class="data row2 col0" >-0.008948</td>
#       <td id="T_c757c_row2_col1" class="data row2 col1" >0.001329</td>
#       <td id="T_c757c_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_c757c_row2_col3" class="data row2 col3" >-0.058142</td>
#       <td id="T_c757c_row2_col4" class="data row2 col4" >0.139581</td>
#       <td id="T_c757c_row2_col5" class="data row2 col5" >-0.092226</td>
#       <td id="T_c757c_row2_col6" class="data row2 col6" >-0.087780</td>
#       <td id="T_c757c_row2_col7" class="data row2 col7" >-0.029548</td>
#     </tr>
#     <tr>
#       <th id="T_c757c_level0_row3" class="row_heading level0 row3" >duration</th>
#       <td id="T_c757c_row3_col0" class="data row3 col0" >-0.033257</td>
#       <td id="T_c757c_row3_col1" class="data row3 col1" >0.042651</td>
#       <td id="T_c757c_row3_col2" class="data row3 col2" >-0.058142</td>
#       <td id="T_c757c_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_c757c_row3_col4" class="data row3 col4" >-0.107962</td>
#       <td id="T_c757c_row3_col5" class="data row3 col5" >0.028698</td>
#       <td id="T_c757c_row3_col6" class="data row3 col6" >0.031175</td>
#       <td id="T_c757c_row3_col7" class="data row3 col7" >0.342469</td>
#     </tr>
#     <tr>
#       <th id="T_c757c_level0_row4" class="row_heading level0 row4" >campaign</th>
#       <td id="T_c757c_row4_col0" class="data row4 col0" >0.037136</td>
#       <td id="T_c757c_row4_col1" class="data row4 col1" >-0.030959</td>
#       <td id="T_c757c_row4_col2" class="data row4 col2" >0.139581</td>
#       <td id="T_c757c_row4_col3" class="data row4 col3" >-0.107962</td>
#       <td id="T_c757c_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_c757c_row4_col5" class="data row4 col5" >-0.112284</td>
#       <td id="T_c757c_row4_col6" class="data row4 col6" >-0.108448</td>
#       <td id="T_c757c_row4_col7" class="data row4 col7" >-0.084054</td>
#     </tr>
#     <tr>
#       <th id="T_c757c_level0_row5" class="row_heading level0 row5" >pdays</th>
#       <td id="T_c757c_row5_col0" class="data row5 col0" >-0.017468</td>
#       <td id="T_c757c_row5_col1" class="data row5 col1" >0.069676</td>
#       <td id="T_c757c_row5_col2" class="data row5 col2" >-0.092226</td>
#       <td id="T_c757c_row5_col3" class="data row5 col3" >0.028698</td>
#       <td id="T_c757c_row5_col4" class="data row5 col4" >-0.112284</td>
#       <td id="T_c757c_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_c757c_row5_col6" class="data row5 col6" >0.985645</td>
#       <td id="T_c757c_row5_col7" class="data row5 col7" >0.154055</td>
#     </tr>
#     <tr>
#       <th id="T_c757c_level0_row6" class="row_heading level0 row6" >previous</th>
#       <td id="T_c757c_row6_col0" class="data row6 col0" >-0.011900</td>
#       <td id="T_c757c_row6_col1" class="data row6 col1" >0.079536</td>
#       <td id="T_c757c_row6_col2" class="data row6 col2" >-0.087780</td>
#       <td id="T_c757c_row6_col3" class="data row6 col3" >0.031175</td>
#       <td id="T_c757c_row6_col4" class="data row6 col4" >-0.108448</td>
#       <td id="T_c757c_row6_col5" class="data row6 col5" >0.985645</td>
#       <td id="T_c757c_row6_col6" class="data row6 col6" >1.000000</td>
#       <td id="T_c757c_row6_col7" class="data row6 col7" >0.169124</td>
#     </tr>
#     <tr>
#       <th id="T_c757c_level0_row7" class="row_heading level0 row7" >deposit</th>
#       <td id="T_c757c_row7_col0" class="data row7 col0" >-0.008750</td>
#       <td id="T_c757c_row7_col1" class="data row7 col1" >0.100295</td>
#       <td id="T_c757c_row7_col2" class="data row7 col2" >-0.029548</td>
#       <td id="T_c757c_row7_col3" class="data row7 col3" >0.342469</td>
#       <td id="T_c757c_row7_col4" class="data row7 col4" >-0.084054</td>
#       <td id="T_c757c_row7_col5" class="data row7 col5" >0.154055</td>
#       <td id="T_c757c_row7_col6" class="data row7 col6" >0.169124</td>
#       <td id="T_c757c_row7_col7" class="data

# %% [markdown]
# **Insights:**
# 1. Very strong correlation between:
#     - pdays and pervious
# 2. Moderately strong correlation between:
#     - duration and deposit

# %% [markdown]
# ### Bivariate Analysis (Relationship between features)

# %%
df.columns
# Out:
# Index(['age', 'job', 'marital', 'education', 'default', 'balance', 'housing',
#        'loan', 'contact', 'day', 'month', 'duration', 'campaign', 'pdays',
#        'previous', 'poutcome', 'deposit'],
#       dtype='object')

# %%
(so
 .Plot((df
        .assign(deposit=np.where(df.deposit==0, "0", "1"))),
       x='pdays',
       y='previous')
 .add(so.Dots(alpha=0.5),
      color='deposit')
 .add(so.Line(color='.2'),
      so.PolyFit(),
      color=None)
 .scale(y=so.Continuous().tick(between=(0, 100)))
 .theme({"axes.prop_cycle": matplotlib.cycler(color=[color_palette[0], color_palette[3]]), "axes.facecolor": "w", "grid.color": "#ffffff"})
)

# %%
(so
 .Plot((df
        .assign(deposit=np.where(df.deposit==0, "0", "1"))),
       y='balance',
       color='deposit')
 .pair(x=['age', 'duration', 'previous'])
 .add(so.Dots(alpha=0.5))
 .theme({"axes.prop_cycle": matplotlib.cycler(color=[color_palette[0], color_palette[3]]), "axes.facecolor": "w", "grid.color": "#ffffff"})
)

# %%
(so
 .Plot((df
 .groupby(['marital', 'education'])
 ['education']
 .describe()
 ["count"]
 .unstack(level=1)
 .reset_index()
 .melt(id_vars='marital', var_name='education', value_name='count')
),
       x='count',
       y='marital',
       color='education')
 .add(so.Bar(),
      so.Agg(),
      so.Dodge())
 .label(x='',
       y='marital',
       color=str.capitalize,
       title=f'Marital / Education count')
 .theme({"axes.prop_cycle": matplotlib.cycler(color=color_palette), "axes.facecolor": "w", "grid.color": "#ffffff"})
)

# %%
(so
 .Plot((df
        .assign(deposit=np.where(df.deposit==0, "0", "1"))), 
       x='default',
       y='balance',
       color='deposit')
 .add(so.Dot(alpha=0.5),
      so.Dodge(),
      so.Jitter(.3))
 .label(x='',
       y='balance',
       color=str.capitalize,
       title=f'Balance / Default / Deposit')
 .theme({"axes.prop_cycle": matplotlib.cycler(color=[color_palette[0], color_palette[3]]), "axes.facecolor": "w", "grid.color": "#ffffff"})
)

# %%
df_cat = pd.concat([df.select_dtypes('object'), df['deposit']], axis=1)

label = LabelEncoder()
df_encoded = pd.DataFrame()

for i in df_cat.columns:
    if i != "deposit":
        df_encoded[i] = label.fit_transform(df_cat[i])
    else:
        df_encoded[i] = label.fit_transform(df_cat[i].values.ravel())
    
def Cramers_V(var1, var2):
    crosstab = np.array(pd.crosstab(index=var1, columns=var2)) # Cross Tab
    return (association(crosstab, method='cramer'))            # Return Cramer's V

# Create the dataFrame matrix with the returned Cramer's V
rows = []

for var1 in df_encoded:
    col = []

    for var2 in df_encoded:
        V = Cramers_V(df_encoded[var1], df_encoded[var2]) # Return Cramer's V
        col.append(V)                                             # Store values to subsequent columns  
        
    rows.append(col)                                              # Store values to subsequent rows
    
CramersV_results = np.array(rows)
CramersV_df = (pd
               .DataFrame(CramersV_results, columns = df_encoded.columns, index = df_encoded.columns)
               .style
               .background_gradient(cmap=cm, axis=None)
               .set_sticky(axis="index")
               .set_sticky(axis="columns"))
CramersV_df
# Out:
# <style type="text/css">
# #T_735f6 thead tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 3 !important;
# }
# #T_735f6 tbody tr th:nth-child(1) {
#   position: sticky;
#   background-color: inherit;
#   left: 0px;
#   z-index: 1;
# }
# #T_735f6 thead tr:nth-child(1) th {
#   position: sticky;
#   background-color: inherit;
#   top: 0px;
#   z-index: 2;
# }
# #T_735f6_row0_col0, #T_735f6_row1_col1, #T_735f6_row2_col2, #T_735f6_row3_col3, #T_735f6_row4_col4, #T_735f6_row5_col5, #T_735f6_row6_col6, #T_735f6_row7_col7, #T_735f6_row8_col8, #T_735f6_row9_col9 {
#   background-color: #152411;
#   color: #f1f1f1;
# }
# #T_735f6_row0_col1, #T_735f6_row0_col4, #T_735f6_row1_col0, #T_735f6_row4_col0, #T_735f6_row4_col6, #T_735f6_row6_col4, #T_735f6_row6_col8, #T_735f6_row7_col8, #T_735f6_row7_col9, #T_735f6_row8_col6, #T_735f6_row8_col7, #T_735f6_row9_col7 {
#   background-color: #644b35;
#   color: #f1f1f1;
# }
# #T_735f6_row0_col2, #T_735f6_row2_col0 {
#   background-color: #dca98e;
#   color: #000000;
# }
# #T_735f6_row0_col3, #T_735f6_row0_col8, #T_735f6_row1_col3, #T_735f6_row1_col4, #T_735f6_row1_col5, #T_735f6_row1_col6, #T_735f6_row1_col7, #T_735f6_row1_col8, #T_735f6_row1_col9, #T_735f6_row2_col3, #T_735f6_row2_col5, #T_735f6_row2_col8, #T_735f6_row2_col9, #T_735f6_row3_col0, #T_735f6_row3_col1, #T_735f6_row3_col2, #T_735f6_row3_col4, #T_735f6_row3_col5, #T_735f6_row3_col6, #T_735f6_row3_col7, #T_735f6_row3_col8, #T_735f6_row3_col9, #T_735f6_row4_col1, #T_735f6_row4_col3, #T_735f6_row4_col5, #T_735f6_row5_col1, #T_735f6_row5_col2, #T_735f6_row5_col3, #T_735f6_row5_col4, #T_735f6_row5_col6, #T_735f6_row5_col8, #T_735f6_row5_col9, #T_735f6_row6_col1, #T_735f6_row6_col3, #T_735f6_row6_col5, #T_735f6_row7_col1, #T_735f6_row7_col3, #T_735f6_row8_col0, #T_735f6_row8_col1, #T_735f6_row8_col2, #T_735f6_row8_col3, #T_735f6_row8_col5, #T_735f6_row9_col1, #T_735f6_row9_col2, #T_735f6_row9_col3, #T_735f6_row9_col5 {
#   background-color: #1e1a0f;
#   color: #f1f1f1;
# }
# #T_735f6_row0_col5, #T_735f6_row0_col6, #T_735f6_row0_col7, #T_735f6_row0_col9, #T_735f6_row1_col2, #T_735f6_row2_col1, #T_735f6_row2_col4, #T_735f6_row2_col6, #T_735f6_row2_col7, #T_735f6_row4_col2, #T_735f6_row4_col8, #T_735f6_row4_col9, #T_735f6_row5_col0, #T_735f6_row5_col7, #T_735f6_row6_col0, #T_735f6_row6_col2, #T_735f6_row6_col9, #T_735f6_row7_col0, #T_735f6_row7_col2, #T_735f6_row7_col5, #T_735f6_row8_col4, #T_735f6_row9_col0, #T_735f6_row9_col4, #T_735f6_row9_col6 {
#   background-color: #3f3128;
#   color: #f1f1f1;
# }
# #T_735f6_row4_col7, #T_735f6_row6_col7, #T_735f6_row7_col4, #T_735f6_row7_col6 {
#   background-color: #d7c9ac;
#   color: #000000;
# }
# #T_735f6_row8_col9, #T_735f6_row9_col8 {
#   background-color: #a76f53;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_735f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_735f6_level0_col0" class="col_heading level0 col0" >job</th>
#       <th id="T_735f6_level0_col1" class="col_heading level0 col1" >marital</th>
#       <th id="T_735f6_level0_col2" class="col_heading level0 col2" >education</th>
#       <th id="T_735f6_level0_col3" class="col_heading level0 col3" >default</th>
#       <th id="T_735f6_level0_col4" class="col_heading level0 col4" >housing</th>
#       <th id="T_735f6_level0_col5" class="col_heading level0 col5" >loan</th>
#       <th id="T_735f6_level0_col6" class="col_heading level0 col6" >contact</th>
#       <th id="T_735f6_level0_col7" class="col_heading level0 col7" >month</th>
#       <th id="T_735f6_level0_col8" class="col_heading level0 col8" >poutcome</th>
#       <th id="T_735f6_level0_col9" class="col_heading level0 col9" >deposit</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_735f6_level0_row0" class="row_heading level0 row0" >job</th>
#       <td id="T_735f6_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_735f6_row0_col1" class="data row0 col1" >0.206012</td>
#       <td id="T_735f6_row0_col2" class="data row0 col2" >0.458259</td>
#       <td id="T_735f6_row0_col3" class="data row0 col3" >0.036533</td>
#       <td id="T_735f6_row0_col4" class="data row0 col4" >0.281740</td>
#       <td id="T_735f6_row0_col5" class="data row0 col5" >0.106502</td>
#       <td id="T_735f6_row0_col6" class="data row0 col6" >0.150465</td>
#       <td id="T_735f6_row0_col7" class="data row0 col7" >0.110240</td>
#       <td id="T_735f6_row0_col8" class="data row0 col8" >0.064214</td>
#       <td id="T_735f6_row0_col9" class="data row0 col9" >0.135990</td>
#     </tr>
#     <tr>
#       <th id="T_735f6_level0_row1" class="row_heading level0 row1" >marital</th>
#       <td id="T_735f6_row1_col0" class="data row1 col0" >0.206012</td>
#       <td id="T_735f6_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_735f6_row1_col2" class="data row1 col2" >0.121622</td>
#       <td id="T_735f6_row1_col3" class="data row1 col3" >0.019230</td>
#       <td id="T_735f6_row1_col4" class="data row1 col4" >0.020685</td>
#       <td id="T_735f6_row1_col5" class="data row1 col5" >0.051937</td>
#       <td id="T_735f6_row1_col6" class="data row1 col6" >0.045091</td>
#       <td id="T_735f6_row1_col7" class="data row1 col7" >0.072317</td>
#       <td id="T_735f6_row1_col8" class="data row1 col8" >0.029083</td>
#       <td id="T_735f6_row1_col9" class="data row1 col9" >0.065926</td>
#     </tr>
#     <tr>
#       <th id="T_735f6_level0_row2" class="row_heading level0 row2" >education</th>
#       <td id="T_735f6_row2_col0" class="data row2 col0" >0.458259</td>
#       <td id="T_735f6_row2_col1" class="data row2 col1" >0.121622</td>
#       <td id="T_735f6_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_735f6_row2_col3" class="data row2 col3" >0.015896</td>
#       <td id="T_735f6_row2_col4" class="data row2 col4" >0.119339</td>
#       <td id="T_735f6_row2_col5" class="data row2 col5" >0.080279</td>
#       <td id="T_735f6_row2_col6" class="data row2 col6" >0.122795</td>
#       <td id="T_735f6_row2_col7" class="data row2 col7" >0.110105</td>
#       <td id="T_735f6_row2_col8" class="data row2 col8" >0.035652</td>
#       <td id="T_735f6_row2_col9" class="data row2 col9" >0.072695</td>
#     </tr>
#     <tr>
#       <th id="T_735f6_level0_row3" class="row_heading level0 row3" >default</th>
#       <td id="T_735f6_row3_col0" class="data row3 col0" >0.036533</td>
#       <td id="T_735f6_row3_col1" class="data row3 col1" >0.019230</td>
#       <td id="T_735f6_row3_col2" class="data row3 col2" >0.015896</td>
#       <td id="T_735f6_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_735f6_row3_col4" class="data row3 col4" >0.006025</td>
#       <td id="T_735f6_row3_col5" class="data row3 col5" >0.077234</td>
#       <td id="T_735f6_row3_col6" class="data row3 col6" >0.024406</td>
#       <td id="T_735f6_row3_col7" class="data row3 col7" >0.058675</td>
#       <td id="T_735f6_row3_col8" class="data row3 col8" >0.040403</td>
#       <td id="T_735f6_row3_col9" class="data row3 col9" >0.022419</td>
#     </tr>
#     <tr>
#       <th id="T_735f6_level0_row4" class="row_heading level0 row4" >housing</th>
#       <td id="T_735f6_row4_col0" class="data row4 col0" >0.281740</td>
#       <td id="T_735f6_row4_col1" class="data row4 col1" >0.020685</td>
#       <td id="T_735f6_row4_col2" class="data row4 col2" >0.119339</td>
#       <td id="T_735f6_row4_col3" class="data row4 col3" >0.006025</td>
#       <td id="T_735f6_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_735f6_row4_col5" class="data row4 col5" >0.041323</td>
#       <td id="T_735f6_row4_col6" class="data row4 col6" >0.213585</td>
#       <td id="T_735f6_row4_col7" class="data row4 col7" >0.504213</td>
#       <td id="T_735f6_row4_col8" class="data row4 col8" >0.143147</td>
#       <td id="T_735f6_row4_col9" class="data row4 col9" >0.139173</td>
#     </tr>
#     <tr>
#       <th id="T_735f6_level0_row5" class="row_heading level0 row5" >loan</th>
#       <td id="T_735f6_row5_col0" class="data row5 col0" >0.106502</td>
#       <td id="T_735f6_row5_col1" class="data row5 col1" >0.051937</td>
#       <td id="T_735f6_row5_col2" class="data row5 col2" >0.080279</td

# %% [markdown]
# **Insights:**
# 1. Moderately strong association between:
#     - job and education
#     - housing and month
#     - contact and month
# 2. Observable association between:
#     - housing and job
#     - month and deposit
#     - poutcome and deposit

# %%
fig, axes = plt.subplots(figsize=(12, 3))
sns.stripplot(data=df, 
              x='job', 
              y=df["balance"], 
              size=2, 
              hue="deposit", 
              palette=[color_palette[0], color_palette[3]], 
              alpha=0.5,
              ax=axes,)
plt.title('Stripplot of Balance v. Job')
plt.tight_layout();

# %%
n_cols = 3
n_elements = len(['marital', 'education', 'default', 'housing', 'loan', 'contact'])
n_rows = np.ceil(n_elements / n_cols).astype("int")

y_value = df["balance"]

fig, axes = plt.subplots(ncols=n_cols, nrows=n_rows, figsize=(15, n_rows * 3.5))

for col, ax in zip(['marital', 'education', 'default', 'housing', 'loan', 'contact'], axes.ravel()):
    sns.stripplot(data=df, x=col, y=y_value, ax=ax, size=1, hue="deposit", palette=[color_palette[0], color_palette[3]], alpha=0.5)

plt.tight_layout();
